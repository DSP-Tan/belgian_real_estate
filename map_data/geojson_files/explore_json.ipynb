# %%
import json
from pathlib import Path

json_file = Path("sh_statbel_statistical_sectors_3812_20240101.geojson")

# %%
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)

#print(json.dumps(data, indent=2))
print(data.keys())
print(data["type"])
print(data["name"])
print(data["crs"])
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])
# FeatureCollection
# sh_statbel_statistical_sectors_3812_20240101
# {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::3812'}}

# %%
feature = data["features"][0]

# %%
print(feature["type"])
print(feature["properties"])
print(feature["geometry"])
# Out:
# Feature
# {'ogc_fid': 1, 'cd_sector': '11001A00-', 'tx_sector_descr_nl': 'AARTSELAAR-CENTRUM', 'tx_sector_descr_fr': 'AARTSELAAR-CENTRUM', 'tx_sector_descr_de': 'AARTSELAAR-CENTRUM', 'cd_sub_munty': '11001A', 'tx_sub_munty_nl': 'AARTSELAAR', 'tx_sub_munty_fr': 'AARTSELAAR', 'tx_munty_dstr': None, 'cd_munty_refnis': '11001', 'tx_munty_descr_nl': 'Aartselaar', 'tx_munty_descr_fr': 'Aartselaar', 'tx_munty_descr_de': 'Aartselaar', 'cd_dstr_refnis': '11000', 'tx_adm_dstr_descr_nl': 'Arrondissement Antwerpen', 'tx_adm_dstr_descr_fr': 'Arrondissement d’Anvers', 'tx_adm_dstr_descr_de': 'Bezirk Antwerpen', 'cd_prov_refnis': '10000', 'tx_prov_descr_nl': 'Provincie Antwerpen', 'tx_prov_descr_fr': 'Province d’Anvers', 'tx_prov_descr_de': 'Provinz Antwerpen', 'cd_rgn_refnis': '02000', 'tx_rgn_descr_nl': 'Vlaams Gewest', 'tx_rgn_descr_fr': 'Région flamande', 'tx_rgn_descr_de': 'Flämische Region', 'cd_country': 'BE', 'cd_nuts_lvl1': 'BE2', 'cd_nuts_lvl2': 'BE21', 'cd_nuts_lvl3': 'BE211', 'ms_area_ha': 53.158100266739645, 'ms_perimeter_m': 5248.0, 'dt_situation': '2024/01/01'}
# {'type': 'MultiPolygon', 'coordinates': [[[[651655.7722000033, 703013.9475000016], [651845.9466999993, 702847.6275999993], [651826.3571999967, 702814.4538000003], [651804.6251000017, 702796.2639000006], [651777.8718999997, 702825.5104999989], [651733.5781999975, 702800.1616000012], [651708.4085000008, 702784.5025999993], [651664.7713000029, 702758.7631999999], [651640.1481999978, 702744.760400001], [651594.2766999975, 702718.4580999985], [651552.3110999987, 702694.4065000005], [651543.0971999988, 702654.0775000006], [651566.6953999996, 702614.9556999989], [651607.1519000009, 702585.1327], [651647.123300001, 702558.6063000001], [651685.9869000018, 702520.8925999999], [651720.9266000018, 702500.5218999982], [651772.6278000027, 702512.0747999996], [651820.1745999977, 702510.9398999996], [651859.6922999993, 702490.5386000015], [651858.7111999989, 702462.804299999], [651845.2771999985, 702435.693500001], [651808.2674999982, 702386.3612999991], [651780.2066999972, 702375.3894000016], [651740.065899998, 702379.2595999986], [651693.1272, 702391.8475000001], [651661.5014000013, 702400.3592999987], [651638.2823000029, 702406.6064999998], [651621.8598999977, 702411.1358999982], [651631.3100000024, 702436.2930000015], [651631.809799999, 702437.6053999998], [651636.2145999968, 702449.3403000012], [651645.9626000002, 702465.8101000004], [651657.4289999977, 702485.1862999983], [651636.177199997, 702501.5742000006], [651616.878700003, 702515.6812000014], [651590.376500003, 702535.5529000014], [651571.2234999985, 702509.8319999985], [651555.7580000013, 702483.2368], [651512.358599998, 702428.8726999983], [651517.3022999987, 702377.6860999987], [651490.4799999967, 702330.0738999993], [651508.2036999986, 702287.9512999989], [651517.4098000005, 702261.1557999998], [651533.3677000031, 702220.5799000002], [651546.3552000001, 702193.7380000018], [651563.3903999999, 702158.5214999989], [651576.9245999977, 702132.9607999995], [651583.7569999993, 702096.7745000012], [651589.7163000032, 702045.5879999995], [651594.2060000002, 702000.5265000015], [651598.8351999968, 701964.6834999993], [651601.2591999993, 701945.9807999991], [651607.8572999984, 701909.7943999991], [651590.9978, 701911.3236000016], [651589.7166000009, 701911.4485], [651589.7951000035, 701907.6829000004], [651591.3823999986, 701830.683699999], [651564.3047999963, 701827.9149000011], [651563.2735999972, 701827.805399999], [651470.947300002, 701818.3570999987], [651446.3383999988, 701815.8383000009], [651434.5481999964, 701761.2749999985], [651382.3601000011, 701770.3781000003], [651372.2459999993, 701810.6578000002], [651353.1296000034, 701870.3425999992], [651325.7072999999, 701875.4017000012], [651309.1877000034, 701909.6182999983], [651300.058600001, 701944.554299999], [651296.2731000036, 701981.2254999988], [651291.1449000016, 702008.4902999997], [651248.2534999996, 702017.7195000015], [651218.2074000016, 702014.4034000002], [651201.1569999978, 702043.7917000018], [651185.7300999984, 702087.6801000014], [651213.0099000037, 702097.886500001], [651240.7110000029, 702113.3429000005], [651250.3039000034, 702118.7034000009], [651276.5367000028, 702130.6281999983], [651268.7964999974, 702179.5956999995], [651262.0414000005, 702222.313099999], [651215.8241999969, 702213.9796999991], [651202.430399999, 702242.1341000013], [651255.0063999966, 702255.436999999], [651246.2047000006, 702297.1856000014], [651244.7509000003, 702301.9197999984], [651238.5917999968, 702326.5909000002], [651238.1541000009, 702327.7938000001], [651227.0569999963, 702358.0736999996], [651201.1823000014, 702356.5548], [651201.6669000015, 702354.8519000001], [651167.4794000015, 702356.7696000002], [651139.7300999984, 702352.3913000003], [651103.3552000001, 702354.1369999982], [651019.0922000036, 702338.0802999996], [651034.9133000001, 702396.3317000009], [651063.4252000004, 702425.9910000004], [651091.9373999983, 702452.228599999], [651119.3087000027, 702481.8878000006], [651137.4318000004, 702496.7181000002], [651141.90010 ...

# %%
for item in feature["properties"].items():
    print(item)
# Out:
# ('ogc_fid', 1)
# ('cd_sector', '11001A00-')
# ('tx_sector_descr_nl', 'AARTSELAAR-CENTRUM')
# ('tx_sector_descr_fr', 'AARTSELAAR-CENTRUM')
# ('tx_sector_descr_de', 'AARTSELAAR-CENTRUM')
# ('cd_sub_munty', '11001A')
# ('tx_sub_munty_nl', 'AARTSELAAR')
# ('tx_sub_munty_fr', 'AARTSELAAR')
# ('tx_munty_dstr', None)
# ('cd_munty_refnis', '11001')
# ('tx_munty_descr_nl', 'Aartselaar')
# ('tx_munty_descr_fr', 'Aartselaar')
# ('tx_munty_descr_de', 'Aartselaar')
# ('cd_dstr_refnis', '11000')
# ('tx_adm_dstr_descr_nl', 'Arrondissement Antwerpen')
# ('tx_adm_dstr_descr_fr', 'Arrondissement d’Anvers')
# ('tx_adm_dstr_descr_de', 'Bezirk Antwerpen')
# ('cd_prov_refnis', '10000')
# ('tx_prov_descr_nl', 'Provincie Antwerpen')
# ('tx_prov_descr_fr', 'Province d’Anvers')
# ('tx_prov_descr_de', 'Provinz Antwerpen')
# ('cd_rgn_refnis', '02000')
# ('tx_rgn_descr_nl', 'Vlaams Gewest')
# ('tx_rgn_descr_fr', 'Région flamande')
# ('tx_rgn_descr_de', 'Flämische Region')
# ('cd_country', 'BE')
# ('cd_nuts_lvl1', 'BE2')
# ('cd_nuts_lvl2', 'BE21')
# ('cd_nuts_lvl3', 'BE211')
# ('ms_area_ha', 53.158100266739645)
# ('ms_perimeter_m', 5248.0)
# ('dt_situation', '2024/01/01')

# %% [markdown]
# Many data points are repeated for each language.

# %%
import geopandas as gpd

gdf = gpd.read_file(json_file)
output_file = "communes.geojson"

# Remove german and dutch duplicates of certain properties, keep only french
gdf = gdf.drop(columns=[col for col in gdf.columns if col.endswith("_nl") or col.endswith("_de")])

## aggregate to commune level
gdf_districts = gdf.dissolve(by="cd_munty_refnis", as_index=False)

gdf_districts.to_file(output_file, driver="GeoJSON")
print(f"Aggregated GeoJSON saved to {output_file}")
# Out:
#        ogc_fid  cd_sector            tx_sector_descr_nl  \
# 0            1  11001A00-            AARTSELAAR-CENTRUM
# 1            2  11001A01-                  DE LEEUWERIK
# 2            3  11001A020                     BUERSTEDE
# 3            4  11001A030                      YSSELAAR
# 4            5  11001A042                 KLEINE GRIPPE
# ...        ...        ...                           ...
# 19790    19791  93090G191                BOIS DE NISMES
# 19791    19792  93090H000                DOURBES-CENTRE
# 19792    19793  93090H012  DOURBES ROUTE DE MARIEMBOURG
# 19793    19794  93090H063                         LORET
# 19794    19795  93090H091               ROCHE A L'HOMME
#
#                  tx_sector_descr_fr            tx_sector_descr_de  \
# 0                AARTSELAAR-CENTRUM            AARTSELAAR-CENTRUM
# 1                      DE LEEUWERIK                  DE LEEUWERIK
# 2                         BUERSTEDE                     BUERSTEDE
# 3                          YSSELAAR                      YSSELAAR
# 4                     KLEINE GRIPPE                 KLEINE GRIPPE
# ...                             ...                           ...
# 19790                BOIS DE NISMES                BOIS DE NISMES
# 19791                DOURBES-CENTRE                DOURBES-CENTRE
# 19792  DOURBES ROUTE DE MARIEMBOURG  DOURBES ROUTE DE MARIEMBOURG
# 19793                         LORET                         LORET
# 19794               ROCHE A L'HOMME               ROCHE A L'HOMME
#
#       cd_sub_munty tx_sub_munty_nl tx_sub_munty_fr tx_munty_dstr  \
# 0           11001A      AARTSELAAR      AARTSELAAR          None
# 1           11001A      AARTSELAAR      AARTSELAAR          None
# 2           11001A      AARTSELAAR      AARTSELAAR          None
# 3           11001A      AARTSELAAR      AARTSELAAR          None
# 4           11001A      AARTSELAAR      AARTSELAAR          None
# ...            ...             ...             ...           ...
# 19790       93090G          NISMES          NISMES          None
# 19791       93090H        DOURBES*        DOURBES*          None
# 19792       93090H        DOURBES*        DOURBES*          None
# 19793       93090H        DOURBES*        DOURBES*          None
# 19794       93090H        DOURBES*        DOURBES*          None
#
#       cd_munty_refnis  ...  tx_rgn_descr_fr     tx_rgn_descr_de cd_country  \
# 0               11001  ...  Région flamande    Flämische Region         BE
# 1               11001  ...  Région flamande    Flämische Region         BE
# 2               11001  ...  Région flamande    Flämische Region         BE
# 3               11001  ...  Région flamande    Flämische Region         BE
# 4               11001  ...  Région flamande    Flämische Region         BE
# ...               ...  ...              ...                 ...        ...
# 19790           93090  ...  Région wallonne  Wallonische Region         BE
# 19791           93090  ...  Région wallonne  Wallonische Region         BE
# 19792           93090  ...  Région wallonne  Wallonische Region         BE
# 19793           93090  ...  Région wallonne  Wallonische Region         BE
# 19794           93090  ...  Région wallonne  Wallonische Region         BE
#
#       cd_nuts_lvl1 cd_nuts_lvl2 cd_nuts_lvl3   ms_area_ha ms_perimeter_m  \
# 0              BE2         BE21        BE211    53.158100         5248.0
# 1              BE2         BE21        BE211    67.114679         3935.0
# 2              BE2         BE21        BE211    28.084364         2202.0
# 3              BE2         BE21        BE211    42.811849         3403.0
# 4              BE2         BE21        BE211    25.561955         2166.0
# ...            ...          ...          ...          ...            ...
# 19790          BE3         BE35        BE353  1509.659985        24448.0
# 19791          BE3         BE35        BE353    19.381889         2569.0
# 19792          BE3         BE35        BE353    19.369719         2411.0
# 19793          BE3         BE35        BE353    24.865503         2559.0
# 19794          BE3         BE35        BE353   902.929149        18787.0
#
#       dt_situation                                           geometry
# 0       2024-01-01  MULTIPOLYGON (((651655.772 703013.948, 651845....
# 1       2024-01-01  MULTIPOLYGON (((651744.222 703170.832, 651731....
# 2       2024-01-01  MULTIPOLYGON (((650632.112 702982.154, 650526....
# 3       2024-01-01  MULTIPOLYGON (((651580.191 703830.135, 651521....
# 4       2024-01-01  MULTIPOLYGON (((651744.222 703170.832, 651727....
# ...            ...                                                ...
# 19790   2024-01-01  MULTIPOLYGON (((666393.853 580212.258, 666391....
# 19791   2024-01-01  MULTIPOLYGON (((665770.613 586586.328, 665766....
# 19792   2024-01-01  MULTIPOLYGON (((665770.613 586586.328, 665713....
# 19793   2024-01-01  MULTIPOLYGON (((665915.891 586864.772, 665871....
# 19794   2024-01-01  MULTIPOLYGON (((668194.388 586808.229, 668180....
#
# [19795 rows x 33 columns]

# %%
gdf.columns
# Out:
# Index(['ogc_fid', 'cd_sector', 'tx_sector_descr_nl', 'tx_sector_descr_fr',
#        'tx_sector_descr_de', 'cd_sub_munty', 'tx_sub_munty_nl',
#        'tx_sub_munty_fr', 'tx_munty_dstr', 'cd_munty_refnis',
#        'tx_munty_descr_nl', 'tx_munty_descr_fr', 'tx_munty_descr_de',
#        'cd_dstr_refnis', 'tx_adm_dstr_descr_nl', 'tx_adm_dstr_descr_fr',
#        'tx_adm_dstr_descr_de', 'cd_prov_refnis', 'tx_prov_descr_nl',
#        'tx_prov_descr_fr', 'tx_prov_descr_de', 'cd_rgn_refnis',
#        'tx_rgn_descr_nl', 'tx_rgn_descr_fr', 'tx_rgn_descr_de', 'cd_country',
#        'cd_nuts_lvl1', 'cd_nuts_lvl2', 'cd_nuts_lvl3', 'ms_area_ha',
#        'ms_perimeter_m', 'dt_situation', 'geometry'],
#       dtype='object')

# %%
gdf = gdf.assign(properties=[clean_properties(p) for p in gdf["properties"]]) if "properties" in gdf.columns else gdf
gdf.columns
# Out:
# Index(['ogc_fid', 'cd_sector', 'tx_sector_descr_nl', 'tx_sector_descr_fr',
#        'tx_sector_descr_de', 'cd_sub_munty', 'tx_sub_munty_nl',
#        'tx_sub_munty_fr', 'tx_munty_dstr', 'cd_munty_refnis',
#        'tx_munty_descr_nl', 'tx_munty_descr_fr', 'tx_munty_descr_de',
#        'cd_dstr_refnis', 'tx_adm_dstr_descr_nl', 'tx_adm_dstr_descr_fr',
#        'tx_adm_dstr_descr_de', 'cd_prov_refnis', 'tx_prov_descr_nl',
#        'tx_prov_descr_fr', 'tx_prov_descr_de', 'cd_rgn_refnis',
#        'tx_rgn_descr_nl', 'tx_rgn_descr_fr', 'tx_rgn_descr_de', 'cd_country',
#        'cd_nuts_lvl1', 'cd_nuts_lvl2', 'cd_nuts_lvl3', 'ms_area_ha',
#        'ms_perimeter_m', 'dt_situation', 'geometry'],
#       dtype='object')

# %%
gdf = gdf.drop(columns=[col for col in gdf.columns if col.endswith("_nl") or col.endswith("_de")])

# %%
gdf
# Out:
#        ogc_fid  cd_sector            tx_sector_descr_fr cd_sub_munty  \
# 0            1  11001A00-            AARTSELAAR-CENTRUM       11001A
# 1            2  11001A01-                  DE LEEUWERIK       11001A
# 2            3  11001A020                     BUERSTEDE       11001A
# 3            4  11001A030                      YSSELAAR       11001A
# 4            5  11001A042                 KLEINE GRIPPE       11001A
# ...        ...        ...                           ...          ...
# 19790    19791  93090G191                BOIS DE NISMES       93090G
# 19791    19792  93090H000                DOURBES-CENTRE       93090H
# 19792    19793  93090H012  DOURBES ROUTE DE MARIEMBOURG       93090H
# 19793    19794  93090H063                         LORET       93090H
# 19794    19795  93090H091               ROCHE A L'HOMME       93090H
#
#       tx_sub_munty_fr tx_munty_dstr cd_munty_refnis tx_munty_descr_fr  \
# 0          AARTSELAAR          None           11001        Aartselaar
# 1          AARTSELAAR          None           11001        Aartselaar
# 2          AARTSELAAR          None           11001        Aartselaar
# 3          AARTSELAAR          None           11001        Aartselaar
# 4          AARTSELAAR          None           11001        Aartselaar
# ...               ...           ...             ...               ...
# 19790          NISMES          None           93090         Viroinval
# 19791        DOURBES*          None           93090         Viroinval
# 19792        DOURBES*          None           93090         Viroinval
# 19793        DOURBES*          None           93090         Viroinval
# 19794        DOURBES*          None           93090         Viroinval
#
#       cd_dstr_refnis             tx_adm_dstr_descr_fr  ... cd_rgn_refnis  \
# 0              11000          Arrondissement d’Anvers  ...         02000
# 1              11000          Arrondissement d’Anvers  ...         02000
# 2              11000          Arrondissement d’Anvers  ...         02000
# 3              11000          Arrondissement d’Anvers  ...         02000
# 4              11000          Arrondissement d’Anvers  ...         02000
# ...              ...                              ...  ...           ...
# 19790          93000  Arrondissement de Philippeville  ...         03000
# 19791          93000  Arrondissement de Philippeville  ...         03000
# 19792          93000  Arrondissement de Philippeville  ...         03000
# 19793          93000  Arrondissement de Philippeville  ...         03000
# 19794          93000  Arrondissement de Philippeville  ...         03000
#
#        tx_rgn_descr_fr cd_country cd_nuts_lvl1 cd_nuts_lvl2 cd_nuts_lvl3  \
# 0      Région flamande         BE          BE2         BE21        BE211
# 1      Région flamande         BE          BE2         BE21        BE211
# 2      Région flamande         BE          BE2         BE21        BE211
# 3      Région flamande         BE          BE2         BE21        BE211
# 4      Région flamande         BE          BE2         BE21        BE211
# ...                ...        ...          ...          ...          ...
# 19790  Région wallonne         BE          BE3         BE35        BE353
# 19791  Région wallonne         BE          BE3         BE35        BE353
# 19792  Région wallonne         BE          BE3         BE35        BE353
# 19793  Région wallonne         BE          BE3         BE35        BE353
# 19794  Région wallonne         BE          BE3         BE35        BE353
#
#         ms_area_ha ms_perimeter_m  dt_situation  \
# 0        53.158100         5248.0    2024-01-01
# 1        67.114679         3935.0    2024-01-01
# 2        28.084364         2202.0    2024-01-01
# 3        42.811849         3403.0    2024-01-01
# 4        25.561955         2166.0    2024-01-01
# ...            ...            ...           ...
# 19790  1509.659985        24448.0    2024-01-01
# 19791    19.381889         2569.0    2024-01-01
# 19792    19.369719         2411.0    2024-01-01
# 19793    24.865503         2559.0    2024-01-01
# 19794   902.929149        18787.0    2024-01-01
#
#                                                 geometry
# 0      MULTIPOLYGON (((651655.772 703013.948, 651845....
# 1      MULTIPOLYGON (((651744.222 703170.832, 651731....
# 2      MULTIPOLYGON (((650632.112 702982.154, 650526....
# 3      MULTIPOLYGON (((651580.191 703830.135, 651521....
# 4      MULTIPOLYGON (((651744.222 703170.832, 651727....
# ...                                                  ...
# 19790  MULTIPOLYGON (((666393.853 580212.258, 666391....
# 19791  MULTIPOLYGON (((665770.613 586586.328, 665766....
# 19792  MULTIPOLYGON (((665770.613 586586.328, 665713....
# 19793  MULTIPOLYGON (((665915.891 586864.772, 665871....
# 19794  MULTIPOLYGON (((668194.388 586808.229, 668180....
#
# [19795 rows x 22 columns]
